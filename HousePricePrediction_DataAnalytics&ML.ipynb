# %%
#Project: Residential Property Market Analysis and House Price Prediction Using SQL, Python, Power BI and ML

# %%
#Problem statement:

#A real-estate company needs a reliable way to estimate residential property prices and understand the factors that influence them. 
#Manual pricing based only on experience may result in overvaluation or undervaluation because house prices depend on several interconnected factors, 
#including location, living area, construction quality, property age, number of rooms, garage capacity and available amenities.

#Objective

#To analyze historical historical property data to identify important price drivers and build a regression model that predicts a house’s selling 
#price.

#Finally, a Power BI dashboard was created to present property market trends, important price drivers, neighborhood-level comparisons and 
#actual-versus-predicted prices. The resulting solution will help real-estate professionals make more consistent and data-driven property pricing 
#decisions.

# %%
#Business questions:
#Which neighbourhoods have the highest house prices?
#How do area, quality and property age affect price?
#Does renovation increase the selling price?
#Which property features are most important?
#How accurately can the model predict SalePrice?
#In which property categories does the model make large errors?

# %%
import numpy as np
import pandas as pd

# Data splitting, cross-validation and tuning
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    RandomizedSearchCV #RandomizedSearchCV is a scikit-learn tool used to find a good combination of hyperparameters for a machine-learning model.
)

# Preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler
)

# Regression algorithms
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor
)

from xgboost import XGBRegressor

# Evaluation
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_squared_log_error,
    r2_score
)

# %%
#Now, we'll load the data
df = pd.read_csv("train.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 #Now, we'll load the data
# ----> 2 df = pd.read_csv("train.csv")
#       3 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print(os.getcwd())
# Out:
# E:\Users\USER
